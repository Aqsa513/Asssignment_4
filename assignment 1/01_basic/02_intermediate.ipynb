# %%
import random

print("High Low Game")

round = 5

def main():
  print("Welcome to the High Low Game")
  print("******************************")

  your_score = 0

  for i in range(round):
    print("Round", i + 1)

    computer_number : int = random.randint(1,100)
    your_number : int = random.randint(1,100)
    print("Your Number:", your_number)

    choice:str = input("""Do you think your number is higher or lower than the computer's number? """)
    higher_and_correct:bool = choice == "higher" and your_number > computer_number
    lower_and_correct:bool = choice == "lower" and your_number < computer_number
    if higher_and_correct or lower_and_correct:
      print("You were right! The computer\'s number was",computer_number)
      your_score += 1
    else:
      print("That\'s incorrect.The computer\'s number was",computer_number)

    print("Your score is now",your_score)
    print()

  print("Thanks for playing!")

if __name__ == "__main__":
  main()
# Out:
# High Low Game
# Welcome to the High Low Game
# ******************************
# Round 1
# Your Number: 37
# Do you think your number is higher or lower than the computer's number? lower
# That's incorrect.The computer's number was 37
# Your score is now 0
#
# Round 2
# Your Number: 93
# Do you think your number is higher or lower than the computer's number? higher
# You were right! The computer's number was 84
# Your score is now 1
#
# Round 3
# Your Number: 36
# Do you think your number is higher or lower than the computer's number? lower
# That's incorrect.The computer's number was 23
# Your score is now 1
#
# Round 4
# Your Number: 88
# Do you think your number is higher or lower than the computer's number? higher
# You were right! The computer's number was 71
# Your score is now 2
#
# Round 5
# Your Number: 90
# Do you think your number is higher or lower than the computer's number? higher
# You were right! The computer's number was 49
# Your score is now 3
#
# Thanks for playing!

# %%
print("Planetary Weight Calculator")

def main():
  print("Welcome to the Planetary Weight Calculator!")
  print("********************************************")

  earth_weight = float(input("Enter your weight on Earth: "))

  gravity_ratios = {
      "Mercury": 0.38,
      "Venus": 0.91,
      "Mars": 0.38,
      "Jupiter": 2.34,
      "Saturn": 1.06,
      "Uranus": 0.92,
      "Neptune": 1.19
  }

  print("\n Select a planet")
  for planet, ratio in gravity_ratios.items():
    print(f'- {planet}')

  planet_choice = input("Enter the name of the planet: ").title()

  if planet_choice in gravity_ratios:
    new_weight = earth_weight * gravity_ratios[planet_choice]
    print(f'your weight on {planet_choice} in {new_weight :.2f}kg')
  else:
    print("Invalid planet choice")

if __name__ == "__main__":
  main()
# Out:
# Planetary Weight Calculator
# Welcome to the Planetary Weight Calculator!
# ********************************************
# Enter your weight on Earth: 23
#
#  Select a planet
# - Mercury
# - Venus
# - Mars
# - Jupiter
# - Saturn
# - Uranus
# - Neptune
# Enter the name of the planet: mars
# your weight on Mars in 8.74kg

# %%
print("Lists and Dicts")

my_list = ["apple","mango","orange","pear","banana"]

def access_element(my_list ,index):
  """Returns the element at the specified index, or an error message if out of range."""
  if 0 <= index < len(my_list):
    return  f'Element at index {index} is {my_list[index]}'
  return 'index out of range'

def modify_element(my_list,index,new_value):
  """Modifies the element at the specified index to the new value."""
  if 0 <= index < len(my_list):
    old_value = my_list[index]
    my_list[index] = new_value
    return f'Element at index {index} modified from {old_value} to {new_value}'
  return 'index out of range'

def slice_list(my_list,start,end):
  """Returns a new list containing the elements from the start index to the end index (exclusive)."""
  if 0 <= start < len(my_list) and 0 <= end <= len(my_list):
    return f'Sliced list : {my_list[start:end]}'
  return ("Invalid slice indicates!")

def list_game():
  print("\n Welcome to the list manipulation")

  my_list = ["apple","mango","orange","pear","banana"]

  while True:
    print("Current list",my_list)

    print("select an operation")
    print("1. Access Element")
    print("2. Modify Element")
    print("3. Slice List")
    print("4. Quit")

    choice = input("Enter your choice (1 - 4):")

    if choice == "1":
      index = int(input("Enter the index element you want to access: "))
      print(access_element(my_list,index))
    elif choice == "2":
      index = int(input("Enter the index element you want to modify: "))
      new_value = input("Enter the new value: ")
      print(modify_element(my_list,index,new_value))
    elif choice == "3":
      start = int(input("Enter the start index for the slice: "))
      end = int(input("Enter the end index for the slice: "))
      print(slice_list(my_list,start,end))
    elif choice == "4":
      print("Exiting the game, Thanks for playing.")
      break
    else:
      print("Invalid choice! please enter a number between i to 4.")

if __name__ == "__main__":
  list_game()
# Out:
# Lists and Dicts
#
#  Welcome to the list manipulation
# Current list ['apple', 'mango', 'orange', 'pear', 'banana']
# select an operation
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1 - 4):1
# Enter the index element you want to access: 3
# Element at index 3 is pear
# Current list ['apple', 'mango', 'orange', 'pear', 'banana']
# select an operation
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1 - 4):2
# Enter the index element you want to modify: 4
# Enter the new value: 2
# Element at index 4 modified from banana to 2
# Current list ['apple', 'mango', 'orange', 'pear', '2']
# select an operation
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1 - 4):3
# Enter the start index for the slice: 1
# Enter the end index for the slice: 3
# Sliced list : ['mango', 'orange']
# Current list ['apple', 'mango', 'orange', 'pear', '2']
# select an operation
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1 - 4):4
# Exiting the game, Thanks for playing.
